# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/geva/Documents/data/business-price-indexes-september-2022-quarter-csv.csv',low_memory=False)

# %%
df
# Out:
#       Series_reference   Period  Data_value STATUS  UNITS  \
# 0           CEPQ.S2371  1996.12       899.0  FINAL  Index
# 1           CEPQ.S2371  1997.03       884.0  FINAL  Index
# 2           CEPQ.S2371  1997.06       925.0  FINAL  Index
# 3           CEPQ.S2371  1997.09       932.0  FINAL  Index
# 4           CEPQ.S2371  1997.12       929.0  FINAL  Index
# ...                ...      ...         ...    ...    ...
# 74301   PPIQ.SQURS2110  2021.09      1328.0  FINAL  Index
# 74302   PPIQ.SQURS2110  2021.12      1342.0  FINAL  Index
# 74303   PPIQ.SQURS2110  2022.03      1391.0  FINAL  Index
# 74304   PPIQ.SQURS2110  2022.06      1432.0  FINAL  Index
# 74305   PPIQ.SQURS2110  2022.09      1459.0  FINAL  Index
#
#                                Subject  \
# 0      Capital Goods Price Index - CEP
# 1      Capital Goods Price Index - CEP
# 2      Capital Goods Price Index - CEP
# 3      Capital Goods Price Index - CEP
# 4      Capital Goods Price Index - CEP
# ...                                ...
# 74301      Producers Price Index - PPI
# 74302      Producers Price Index - PPI
# 74303      Producers Price Index - PPI
# 74304      Producers Price Index - PPI
# 74305      Producers Price Index - PPI
#
#                                                    Group  \
# 0      Price Index by Item - Plant, Machinery and Equ...
# 1      Price Index by Item - Plant, Machinery and Equ...
# 2      Price Index by Item - Plant, Machinery and Equ...
# 3      Price Index by Item - Plant, Machinery and Equ...
# 4      Price Index by Item - Plant, Machinery and Equ...
# ...                                                  ...
# 74301  Outputs (ANZSIC06) - NZSIOC level 4, Base: Dec...
# 74302  Outputs (ANZSIC06) - NZSIOC level 4, Base: Dec...
# 74303  Outputs (ANZSIC06) - NZSIOC level 4, Base: Dec...
# 74304  Outputs (ANZSIC06) - NZSIOC level 4, Base: Dec...
# 74305  Outputs (ANZSIC06) - NZSIOC level 4, Base: Dec...
#
#                  Series_title_1 Series_title_2  Series_title_3  \
# 0      Glass and glass products            NaN             NaN
# 1      Glass and glass products            NaN             NaN
# 2      Glass and glass products            NaN             NaN
# 3      Glass and glass products            NaN             NaN
# 4      Glass and glass products            NaN             NaN
# ...                         ...            ...             ...
# 74301    Repair and Maintenance            NaN             NaN
# 74302    Repair and Maintenance            NaN             NaN
# 74303    Repair and Maintenance            NaN             NaN
# 74304    Repair and Maintenance            NaN             NaN
# 74305    Repair and Maintenance            NaN             NaN
#
#        Series_title_4  Series_title_5
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 74301             NaN             NaN
# 74302             NaN             NaN
# 74303             NaN             NaN
# 74304             NaN             NaN
# 74305             NaN             NaN
#
# [74306 rows x 12 columns]

# %%
idx = df.groupby(['Series_reference'])['Period'].transform(max) == df['Period']
df[idx]
# Out:
#       Series_reference   Period  Data_value STATUS  UNITS  \
# 103         CEPQ.S2371  2022.09      1422.0  FINAL  Index
# 207         CEPQ.S2381  2022.09      1628.0  FINAL  Index
# 311         CEPQ.S2389  2022.09      1430.0  FINAL  Index
# 415         CEPQ.S2421  2022.09      2822.0  FINAL  Index
# 519         CEPQ.S2422  2022.09      1928.0  FINAL  Index
# ...                ...      ...         ...    ...    ...
# 73849   PPIQ.SQURS1000  2022.09      1229.0  FINAL  Index
# 73963   PPIQ.SQURS1100  2022.09      1229.0  FINAL  Index
# 74077   PPIQ.SQURS2000  2022.09      1371.0  FINAL  Index
# 74191   PPIQ.SQURS2100  2022.09      1371.0  FINAL  Index
# 74305   PPIQ.SQURS2110  2022.09      1459.0  FINAL  Index
#
#                                Subject  \
# 103    Capital Goods Price Index - CEP
# 207    Capital Goods Price Index - CEP
# 311    Capital Goods Price Index - CEP
# 415    Capital Goods Price Index - CEP
# 519    Capital Goods Price Index - CEP
# ...                                ...
# 73849      Producers Price Index - PPI
# 73963      Producers Price Index - PPI
# 74077      Producers Price Index - PPI
# 74191      Producers Price Index - PPI
# 74305      Producers Price Index - PPI
#
#                                                    Group  \
# 103    Price Index by Item - Plant, Machinery and Equ...
# 207    Price Index by Item - Plant, Machinery and Equ...
# 311    Price Index by Item - Plant, Machinery and Equ...
# 415    Price Index by Item - Plant, Machinery and Equ...
# 519    Price Index by Item - Plant, Machinery and Equ...
# ...                                                  ...
# 73849  Outputs (ANZSIC06) - NZSIOC level 2, Base: Dec...
# 73963  Outputs (ANZSIC06) - NZSIOC level 3, Base: Dec...
# 74077  Outputs (ANZSIC06) - NZSIOC level 2, Base: Dec...
# 74191  Outputs (ANZSIC06) - NZSIOC level 3, Base: Dec...
# 74305  Outputs (ANZSIC06) - NZSIOC level 4, Base: Dec...
#
#                                           Series_title_1 Series_title_2  \
# 103                             Glass and glass products            NaN
# 207                                            Furniture            NaN
# 311                      Other manufactured articles nec            NaN
# 415          Structural metal products and parts thereof            NaN
# 519    Tanks, Reservoirs, and containers of iron, ste...            NaN
# ...                                                  ...            ...
# 73849                       Arts and Recreation Services            NaN
# 73963                       Arts and Recreation Services            NaN
# 74077                                     Other Services            NaN
# 74191                                     Other Services            NaN
# 74305                             Repair and Maintenance            NaN
#
#        Series_title_3  Series_title_4  Series_title_5
# 103               NaN             NaN             NaN
# 207               NaN             NaN             NaN
# 311               NaN             NaN             NaN
# 415               NaN             NaN             NaN
# 519               NaN             NaN             NaN
# ...               ...             ...             ...
# 73849             NaN             NaN             NaN
# 73963             NaN             NaN             NaN
# 74077             NaN             NaN             NaN
# 74191             NaN             NaN             NaN
# 74305             NaN             NaN             NaN
#
# [780 rows x 12 columns]
