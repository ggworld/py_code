# %%
# """
# using site :
# https://onlinepngtools.com/convert-base64-to-png
# 
import boto3
s3 = boto3.resource('s3')
object = s3.Object('reseller', 'my/key/including/filename.jpg')
# object.put(Body=some_binary_data)

import base64
imgstring='''...'''
imgstring='''...'''
imgdata = base64.b64decode(imgstring)
object.put(Body=imgdata)

filename = 'some_image.jpg'  # I assume you have a way of picking unique filenames
# to file 
with open('/Users/allcloud/Documents/a.jpg', 'wb') as f:
    f.write(imgdata)
# Out:
# 'hello '
